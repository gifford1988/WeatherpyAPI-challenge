# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Setup Depeindencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
import urllib
from pprint import pprint

# import/hide api keys
from api_keys import api_key
api_key = f'&APPID={api_key}'

# url for openweathermap 
url = 'http://api.openweathermap.org/data/2.5/weather?q=' + api_key
print(url)


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations based on a uniform distribution
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to the cities list
    if city not in cities:
        cities.append(city)

# Print the total number for the city count in cities to to confirm sufficient count
len(cities)
# Out:
# 614

# %%
# set list for city info
city_info = []

# %%
# print to log beginning of call
print("Beginning Data Retrieval")
print('------------------------')

# set counters
record_count = 1
set_count = 1

# loops through all cities in the list
# enumerate function adds a counter to an iterable and returns it 
# based on the object enumerated
for i, city in enumerate(cities):
    
    
    # group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        
    # create an endpoint url with each city    
    city_url = url + "&q=" + urllib.request.pathname2url(city)
    
    # log url, record and set numbers for the city data
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    print(city_url)
    
    # add 1 to the record counter
    record_count += 1
    
    # run an API request for each of the cities
    try:
          # parse the json and retrieve data
          city_weather = requests.get(city_url).json()
        
          # parse out the max temp, humidity, clouds, and wind speed
          city_lat = city_weather['coord']['lat']
          city_lng = city_weather['coord']['lng']
          city_max_temp = city_weather['main']['temp_max']
          city_humidity = city_weather['main']['humidity']
          city_clouds = city_weather['clouds']['all']
          city_wind = city_weather['wind']['speed']
          city_country = city_weather['sys']['country']
          city_date = city_weather['dt']
          
          # append information into a dataframe
          cityinfo.append({'City':city,
                          'Lats':city_lat,
                          'Lngs':city_lng,
                          'Temp':city_max_temp,
                          'Humidities':city_humidity,
                          'Cloudy':city_clouds,
                          'Wind':city_wind,
                          'Country':city_country,
                          'Date':city_date})
            
    # if an error is experienced skip it
    except:
          print('City not found. Skipping...')
          pass

# indicate when the load is complete
print('-----------------------')
print('Data Retrieval Complete')
print('-----------------------')
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=rikitea
# City not found. Skipping...
# Processing Record 2 of Set 1 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=havre-saint-pierre
# City not found. Skipping...
# Processing Record 3 of Set 1 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=vila%20franca%20do%20campo
# City not found. Skipping...
# Processing Record 4 of Set 1 | mkushi
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=mkushi
# City not found. Skipping...
# Processing Record 5 of Set 1 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=petropavlovsk-kamchatskiy
# City not found. Skipping...
# Processing Record 6 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=port%20alfred
# City not found. Skipping...
# Processing Record 7 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=punta%20arenas
# City not found. Skipping...
# Processing Record 8 of Set 1 | inhambane
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=inhambane
# City not found. Skipping...
# Processing Record 9 of Set 1 | torbay
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=torbay
# City not found. Skipping...
# Processing Record 10 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=mataura
# City not found. Skipping...
# Processing Record 11 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=vaini
# City not found. Skipping...
# Processing Record 12 of Set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=nikolskoye
# City not found. Skipping...
# Processing Record 13 of Set 1 | utiroa
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=utiroa
# City not found. Skipping...
# Processing Record 14 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=busselton
# City not found. Skipping...
# Processing Record 15 of Set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=tuktoyaktuk
# City not found. Skipping...
# Processing Record 16 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=cape%20town
# City not found. Skipping...
# Processing Record 17 of Set 1 | mathathane
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=mathathane
# City not found. Skipping...
# Processing Record 18 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=hermanus
# City not found. Skipping...
# Processing Record 19 of Set 1 | brae
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=brae
# City not found. Skipping...
# Processing Record 20 of Set 1 | biltine
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=kahului
# City not found. Skipping...
# Processing Record 46 of Set 11 | verkh-tula
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=verkh-tula
# City not found. Skipping...
# Processing Record 47 of Set 11 | itaituba
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=itaituba
# City not found. Skipping...
# Processing Record 48 of Set 11 | koygorodok
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=koygorodok
# City not found. Skipping...
# Processing Record 49 of Set 11 | buy
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=buy
# City not found. Skipping...
# Processing Record 0 of Set 12 | mpika
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=mpika
# City not found. Skipping...
# Processing Record 1 of Set 12 | skjervoy
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=skjervoy
# City not found. Skipping...
# Processing Record 2 of Set 12 | bonthe
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=bonthe
# City not found. Skipping...
# Processing Record 3 of Set 12 | looc
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=looc
# City not found. Skipping...
# Processing Record 4 of Set 12 | kuche
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=kuche
# City not found. Skipping...
# Processing Record 5 of Set 12 | ancona
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=ancona
# City not found. Skipping...
# Processing Record 6 of Set 12 | pedro ii
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=pedro%20ii
# City not found. Skipping...
# Processing Record 7 of Set 12 | simoes
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=simoes
# City not found. Skipping...
# Processing Record 8 of Set 12 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=pacific%20grove
# City not found. Skipping...
# Processing Record 9 of Set 12 | tabiauea
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 12 | varna
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=varna
# City not found. Skipping...
# Processing Record 11 of Set 12 | dale
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=dale
# City not found. Skipping...
# Processing Record 12 of Set 12 | pringsewu
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=pringsewu
# City not found. Skipping...
# Processing Record 13 of Set 12 | mizan teferi
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=mizan%20teferi
# City not found. Skipping...
# Processing Record 14 of Set 12 | pouebo
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=pouebo
# City not found. Skipping...
# Processing Record 15 of Set 12 | osinki
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=osinki
# City not found. Skipping...
# Processing Record 16 of Set 12 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=lavrentiya
# City not found. Skipping...
# Processing Record 17 of Set 12 | aljezur
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=aljezur
# City not found. Skipping...
# Processing Record 18 of Set 12 | kodaikanal
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=kodaikanal
# City not found. Skipping...
# Processing Record 19 of Set 12 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=udachnyy
# City not found. Skipping...
# Processing Record 20 of Set 12 | cuprija
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=cuprija
# City not found. Skipping...
# Processing Record 21 of Set 12 | limbang
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=limbang
# City not found. Skipping...
# Processing Record 22 of Set 12 | arman
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=arman
# City not found. Skipping...
# Processing Record 23 of Set 12 | ji-parana
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=ji-parana
# City not found. Skipping...
# Processing Record 24 of Set 12 | dongying
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=dongying
# City not found. Skipping...
# Processing Record 25 of Set 12 | daru
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=daru
# City not found. Skipping...
# Processing Record 26 of Set 12 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=cap%20malheureux
# City not found. Skipping...
# Processing Record 27 of Set 12 | owando
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=owando
# City not found. Skipping...
# Processing Record 28 of Set 12 | divnogorsk
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=divnogorsk
# City not found. Skipping...
# Processing Record 29 of Set 12 | mazatlan
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=mazatlan
# City not found. Skipping...
# Processing Record 30 of Set 12 | tombouctou
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=tombouctou
# City not found. Skipping...
# Processing Record 31 of Set 12 | avera
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=avera
# City not found. Skipping...
# Processing Record 32 of Set 12 | ngaoundere
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=ngaoundere
# City not found. Skipping...
# Processing Record 33 of Set 12 | haines junction
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=haines%20junction
# City not found. Skipping...
# Processing Record 34 of Set 12 | korhogo
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=korhogo
# City not found. Skipping...
# Processing Record 35 of Set 12 | ust-tsilma
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=ust-tsilma
# City not found. Skipping...
# Processing Record 36 of Set 12 | cabanas
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=cabanas
# City not found. Skipping...
# Processing Record 37 of Set 12 | kaeo
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=kaeo
# City not found. Skipping...
# Processing Record 38 of Set 12 | derzhavinsk
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=derzhavinsk
# City not found. Skipping...
# Processing Record 39 of Set 12 | staryy nadym
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=staryy%20nadym
# City not found. Skipping...
# Processing Record 40 of Set 12 | yining
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=yining
# City not found. Skipping...
# Processing Record 41 of Set 12 | palana
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=palana
# City not found. Skipping...
# Processing Record 42 of Set 12 | te anau
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=te%20anau
# City not found. Skipping...
# Processing Record 43 of Set 12 | west plains
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=west%20plains
# City not found. Skipping...
# Processing Record 44 of Set 12 | katherine
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=katherine
# City not found. Skipping...
# Processing Record 45 of Set 12 | calama
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=calama
# City not found. Skipping...
# Processing Record 46 of Set 12 | gondar
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=gondar
# City not found. Skipping...
# Processing Record 47 of Set 12 | korla
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=korla
# City not found. Skipping...
# Processing Record 48 of Set 12 | diu
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=diu
# City not found. Skipping...
# Processing Record 49 of Set 12 | bereda
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=bereda
# City not found. Skipping...
# Processing Record 0 of Set 13 | coulihaut
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=coulihaut
# City not found. Skipping...
# Processing Record 1 of Set 13 | muros
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=muros
# City not found. Skipping...
# Processing Record 2 of Set 13 | pocerski pricinovic
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=pocerski%20pricinovic
# City not found. Skipping...
# Processing Record 3 of Set 13 | labutta
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=labutta
# City not found. Skipping...
# Processing Record 4 of Set 13 | orhangazi
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=orhangazi
# City not found. Skipping...
# Processing Record 5 of Set 13 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=mitsamiouli
# City not found. Skipping...
# Processing Record 6 of Set 13 | aasiaat
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=aasiaat
# City not found. Skipping...
# Processing Record 7 of Set 13 | tubruq
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=tubruq
# City not found. Skipping...
# Processing Record 8 of Set 13 | adrar
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=adrar
# City not found. Skipping...
# Processing Record 9 of Set 13 | bulawayo
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=bulawayo
# City not found. Skipping...
# Processing Record 10 of Set 13 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=mandalgovi
# City not found. Skipping...
# Processing Record 11 of Set 13 | alytus
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=alytus
# City not found. Skipping...
# Processing Record 12 of Set 13 | alausi
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=alausi
# City not found. Skipping...
# Processing Record 13 of Set 13 | freetown
# http://api.openweathermap.org/data/2.5/weather?q=&APPID=ce325497f350f9f79a464e8484b87013&q=freetown
# City not found. Skipping...
# -----------------------
# Data Retrieval Complete
# -----------------------

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Base url for API call
url2 = 'http://api.openweathermap.org/data/2.5/weather?q=' 

# set information from the url API call into respective lists
New_Cities = []
Clouds = []
Countries = []
Humidities = []
Latitudes = []
Longitudes = []
Max_Temperatures = []
Wind_Speeds = []
Dates = []

# set forloop for the unique city for the different lng/lat of the cities data
for city in cities:
        
    Weather = requests.get(url2 + city + api_key).json()
        #pprint(Weather)
    
    if Weather['cod'] == 200:
        
        # append the information from the cities into the respective lists
        New_Cities.append(city)
            
        Cloudiness = Weather['clouds']['all']
        Clouds.append(Cloudiness)
    
        Country = Weather['sys']['country']
        Countries.append(Country)
    
        Humidity = Weather['main']['humidity']
        Humidities.append(Humidity)
    
        Lat = Weather['coord']['lat']
        Latitudes.append(Lat)
    
        Lng = Weather['coord']['lon']
        Longitudes.append(Lng)
    
        Max_Temp = Weather['main']['temp_max']
        Max_Temperatures.append(Max_Temp)
    
        Wind_Speed = Weather['wind']['speed']
        Wind_Speeds.append(Wind_Speed)
    
        Date = Weather['dt']
        Dates.append(Date)
        
# confirmation data retrieval is complete
print('Data Retrieval Complete')

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# using an f series, print the number of data points in the respective categories
print(f"cities: {len(New_Cities)}")
print(f"Clouds: {len(Clouds)}")
print(f"Countries: {len(Countries)}")
print(f"Humidities: {len(Humidities)}")
print(f"Latitudes: {len(Latitudes)}")
print(f"Longitudes: {len(Longitudes)}")
print(f"Max Temperatures: {len(Max_Temperatures)}")
print(f"Wind Speeds: {len(Wind_Speeds)}")
print(f"Dates: {len(Dates)}")
# Out:
# cities: 0
# Clouds: 0
# Countries: 0
# Humidities: 0
# Latitudes: 0
# Longitudes: 0
# Max Temperatures: 0
# Wind Speeds: 0
# Dates: 0

# %%
# build a datafram using a new title and adding the appended info from the lists
city_data = pd.DataFrame({'City': New_Cities,
                           'Cloudiness': Clouds,
                           'Country': Countries,
                           'Date' : Dates,
                           'Humidity': Humidities,
                           'Lat': Latitudes,
                           'Lng': Longitudes,
                           'Max Temp': Max_Temperatures,
                           'Wind Speed': Wind_Speeds})

city_data.head()

output_data_file = "output_data/city_data.csv"
city_data.to_csv(output_data_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-96d36d47a513> in <module>
#      13
#      14 output_data_file = "output_data/city_data.csv"
# ---> 15 city_data.to_csv(output_data_file)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     155             f, handles = _get_handle(self.path_or_buf, self.mode,
#     156                                      encoding=self.encoding,
# --> 157                                      compression=self.compression)
#     158             close = True
#     159
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     422         elif encoding:
#     423             # Python 3 and encoding
# --> 424             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     425         elif is_text:
#     426             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_data/city_data.csv'

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# set a scatterplot for the max temp
sns.set()
plt.scatter(city_data["Lat"], city_data["Max Temp"], marker="o", edgecolor='black', linewidth=1)

# Incorporate title, x and y label, and grids inth the graph properties
plt.title("City Latitude vs. Temperature (F)" + time.strftime('%x'))
plt.ylabel("Temperature")
plt.xlabel("Latitutde")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Temp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# set a scatter plot for the humidity of the cities
sns.set()
plt.scatter(city_data["Lat"], city_data["Humidity"], marker="o", edgecolor='black', linewidth=1)

# Incorporate title, x and y label, and grids inth the graph properties
plt.title("City Latitude vs. Humidity (%)" + time.strftime('%x'))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitutde")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# set a scatter plot for the cloudiness of the cities
sns.set()
plt.scatter(city_data["Lat"], city_data["Cloudiness"], marker="o", edgecolor='black', linewidth=1)

# Incorporate title, x and y label, and grids inth the graph properties
plt.title("City Latitude vs. Cloudiness (%)" + time.strftime('%x'))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitutde")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# set a scatter plot for the wind speed of the cities
sns.set()
plt.scatter(city_data["Lat"], city_data["Wind Speed"], marker="o", edgecolor='black', linewidth=1)

# Incorporate title, x and y label, and grids inth the graph properties
plt.title("City Latitude vs. Windspeed (mph)" + time.strftime('%x'))
plt.ylabel("Windspeed (mph)")
plt.xlabel("Latitutde")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Windspeed.png")

# Show plot
plt.show()

# %%
output_data_file = "output_data/cities.csv"
